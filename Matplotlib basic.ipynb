# %%
# Matplotlib is one of Python’s most important libraries used for data visualization.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.arange(10)

# %%
# %matplotlib inline

# %%
plt.plot(data) # if we give only one value to plot function to it take as y and generate x accordingly

# %%
plt.title("just starting") # adding title of graph
# Out:
# Text(0.5, 1.0, 'just starting')

# %%
plt.xlabel("speed")
# Out:
# Text(0.5, 0, 'speed')

# %%
plt.ylabel("time")
# Out:
# Text(0, 0.5, 'time')

# %%
d = np.arange(0.,5.,0.2)

# %%
d
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4,
#        2.6, 2.8, 3. , 3.2, 3.4, 3.6, 3.8, 4. , 4.2, 4.4, 4.6, 4.8])

# %%
plt.plot(d,d,'r--',d,d**2,'bs',d,d**3,'g^') # There is a third argument in the plot function after the x and y values. 
# this argument shows the line type and color of the chart This setting defaults to “b-” ie b, the line color is blue, and the “-” symbol means the straight line
plt.savefig("my-diagram.png") # this save the image
plt.savefig("my-diagram2.png" , dpi = 400 , bbox_inches = 'tight')  #the dpi is used for resolution of image

# %%
# %matplotlib notebook

# %%
# In Matplotlib, graphics are designed with a Figure object

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
ax1 = fig.add_subplot(2,2,1)

# %%
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

# %%
data = np.random.randn(50) # array of 50 random number

# %%
ax1.plot(data , 'k--')
ax2.plot(data , 'r-')
ax3.plot(data , 'b.')

# %% [markdown]
# ## Color, Markings, and Line Styles

# %%
x = [1,2,3,4,5]
y = [10,11,12,13,14]

# %%
fig = plt.figure()  # create a graphic object
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
ax = fig.add_subplot(2,2,1)

# %%
ax.plot(x , y , "r--")  # third argument is the color and the line style

# %%
# we can write in differently

# %%
ax2 = fig.add_subplot(2,2,2)

# %%
ax2.plot(x , y , linestyle = '--' , color = 'r') # write saperately

# %%
ax3 = fig.add_subplot(2,2,3)

# %%
# %matplotlib inline

# %%
plt.plot(data , 'k--' , label = "default")

# %%
plt.plot(data , 'k--' ,drawstyle = 'steps-post' , label = "default") #stepwise graph

# %%
plt.plot(data , 'k--' ,drawstyle = 'steps-post' , label = "default") #stepwise graph

# %%
plt.plot(data , 'k--' ,drawstyle = 'steps-post' , label = "stepwise") 
plt.legend(loc = 'best') # loc tell the location and legend is used to see label

# %% [markdown]
# ## Thickness, Label, and Legend

# %%
# %matplotlib notebook

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
ax = fig.add_subplot(1,1,1)

# %%
ax.plot(data)

# %%
location = ax.set_xticks([0,10,20,30,40 , 50])
label = ax.set_xticklabels(['one','two','three','four','five','six'], rotation = 20 , fontsize = 'small')  # this is used to set label for x axis

# %%
ax.set_title('Ritesh graph')
# Out:
# Text(0.5, 1.0, 'Ritesh graph')

# %%
ax.set_xlabel("stages")
ax.set_ylabel("anything")  # setting x label and y label
# Out:
# Text(28.25, 0.5, 'anything')
